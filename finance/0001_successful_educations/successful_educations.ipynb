# %%
import pandas as pd

# %%
df = pd.read_csv('successful_educations.csv')

# %%
"""
Most successful people work in professions such as Entrepreneurs, Business Executives, Tech CEOs, and Tech Executives.
"""

df.groupby('Profession')['Name'].count().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Profession'>

# %%
"""
Most successful people degree is Bachelor , Note : Drop Out is the fifth in ranking !! :D
I don't think the degree matters.
"""

df.groupby('Degree')['Name'].count().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Degree'>

# %%
"""
People Who without degrees or droped out :D
"""

df[df['Degree'].isin(['Dropped Out', 'No Degree', 'Dropout'])]
# Out:
#                Name    Profession       Degree  \
# 1        Bill Gates  Entrepreneur  Dropped Out
# 9   Mark Zuckerberg  Entrepreneur  Dropped Out
# 59    Larry Ellison  Entrepreneur      Dropout
# 60     Michael Dell  Entrepreneur      Dropout
# 68     Gautam Adani  Entrepreneur      Dropout
# 77    Gina Rinehart      Business      Dropout
# 80   Giorgio Armani       Fashion      Dropout
# 93     He Xiangjian  Entrepreneur    No Degree
#
#                               Field            Institution  Graduation Year  \
# 1                  computer science     Harvard University           1975.0
# 9   computer science and psychology     Harvard University              NaN
# 59                 Computer Science  University of Chicago              NaN
# 60                          Biology    University of Texas              NaN
# 68                         Commerce     Gujarat University              NaN
# 77                        Economics   University of Sydney              NaN
# ...

# %%
"""
Computer Science Field is Shining :D
almost there is many mistakes and noises in data
i dont want to fix them ... i dont care about this :D
"""

df.groupby('Field')['Name'].count().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Field'>

# %%
"""
i didnt like this data at all
"""
